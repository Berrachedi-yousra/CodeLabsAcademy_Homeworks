# %%
import pandas as pd
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('clustering_data.csv')

df
# Out:
#       -5.462513918787130329e+00  -8.113541922364099435e+00
# 0                     -1.730536                   1.619807
# 1                     -1.178714                   4.515808
# 2                     -6.460586                  -3.068022
# 3                     -1.539308                   5.260561
# 4                    -11.067681                  -4.651872
# ...                         ...                        ...
# 9994                  -2.364366                   3.486911
# 9995                  -4.972361                   7.075455
# 9996                  -7.344465                   7.689617
# 9997                  -1.754597                  -0.577691
# 9998                  -0.939345                   1.282297
#
# [9999 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

x = df.iloc[: , :].values

distorsions = []
for k in range(2, 20):
    kmeans = KMeans(n_clusters = k)
    kmeans.fit(x)
    distorsions.append(kmeans.inertia_)

plt.plot(range(2,20), distorsions)
plt.grid(True)

# %%
Y_pred = KMeans(n_clusters = 6, init = 'random', random_state = 1).fit_predict(x)

# %%
plt.scatter(x[:, 0], x[:, 1], c = Y_pred)
